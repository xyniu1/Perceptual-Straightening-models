# %%
import torch
import matplotlib.pyplot as plt

# %%
x = torch.linspace(0, 9, 100)
y = torch.sin(x)
plt.plot(y)

# %%
f = torch.fft.rfft(y)
plt.plot(torch.sqrt(f * f.conj()))
# Out:
# /scratch/xn314/anaconda3/envs/env_manifold/lib/python3.9/site-packages/torch/_tensor.py:680: ComplexWarning: Casting complex values to real discards the imaginary part
#   return self.numpy().astype(dtype, copy=False)

# %%
f.conj
# Out:
# <function Tensor.conj>
